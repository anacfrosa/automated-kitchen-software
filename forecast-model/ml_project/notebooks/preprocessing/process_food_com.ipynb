# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../../'))  # Adjust path to root directory ml_project

from src.preprocessing.find_ingredient_recipes import process_food_com_recipes
from src.utils.utils import load_file

# %%
# Simplify food.com large wac file 

food_com__large_file = '../data/wac/food_com_db_w_units.csv'  # dataset with food recipes from food.com
df_food_com_large = load_file(food_com__large_file)
## Group each food.com recipe (ingredients, measures, units, servings)
df_processed_food_com = process_food_com_recipes(df_food_com_large)
df_processed_food_com.to_csv('../data/wac/food_com_db_processed.csv', index=False)
