# %%
data_str = "['salt', 'tomato', nan]"
data_str = data_str.replace('nan', 'np.nan')
data_list = eval(data_str)
print(data_list)
# Out:
# ['salt', 'tomato', nan]

# %%
# from sklearn.preprocessing import MinMaxScaler

# # Identify numeric and categorical columns
# numeric_columns = [col for col in shifted_df.columns if 'Qty' in col or col == 'Quantity']
# #categorical_columns = [col for col in shifted_df.columns if 'DayT' in col]

# # Scale only the numeric columns
# scaler = MinMaxScaler((-1, 1))
# shifted_df[numeric_columns] = scaler.fit_transform(shifted_df[numeric_columns])
